# %% [markdown]
# <a href="https://colab.research.google.com/github/tmquan11032003/Web_Scraping/blob/main/Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the required libraries for the scrapping
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup

# %%
# create a get request from the website. 200 means access was granted.
req = requests.get ("https://finance.yahoo.com/most-active")
status = req.status_code
print(status)
# Out:
# 200

# %%
#creating a soup to parse the HTML
content = req.text
soup = BeautifulSoup(content, "html.parser")

# %%
# Extracting the data from the website through its HTML

# primary tag which holds the entire table data
table = soup.find('table', {'class':"W(100%)"})

# secondary tag which holds the certain table information and corresponding tag using CSS selector
stock_data = table.select('tr[class*="simpTblRow Bgc($hoverBgColor):h BdB Bdbc($seperatorColor) Bdbc($tableBorderBlue):h H(32px)"]')

# %%
# looping
name = []
price = []
change = []
per_change = []
volume = []
avg_vol = []
market_cap = []
PE = []

for s in stock_data:
    names = s.find('td', {'aria-label':'Name'}).text
    name.append(names)

    prices = s.find('td', {'aria-label':'Price (Intraday)'}).text
    price.append(prices)

    changes = s.find('td', {'aria-label':'Change'}).text
    change.append(changes)

    per_changes = s.find('td', {'aria-label':'% Change'}).text
    per_change.append(per_changes)

    volumes = s.find('td', {'aria-label':'Volume'}).text
    volume.append(volumes)

    avg_vols = s.find('td', {'aria-label':"Avg Vol (3 month)"}).text
    avg_vol.append(avg_vols)

    markets = s.find('td', {'aria-label':'Market Cap'}).text
    market_cap.append(markets)

    PEs = s.find('td', {'aria-label':'PE Ratio (TTM)'}).text
    PE.append(PEs)

# %%
# create a dictionary with the data before putting it in a dataframe
my_stock = {'Company Name':name, 'Stock_Price':price, 'Company_Change':change,
            'Percent_Change':per_change, 'Volume':volume, 'Average_Vol':avg_vol,
           'Market':market_cap, 'PE Ratio':PE}

# %%
#puttin the data in a dataframe
df = pd.DataFrame(my_stock)
df.head(10)
# Out:
#                       Company Name Stock_Price Company_Change Percent_Change  \
# 0  Marathon Digital Holdings, Inc.       26.71          +1.93         +7.79%
# 1                      Tesla, Inc.      252.54          -1.96         -0.77%
# 2                         NIO Inc.        8.42          +0.13         +1.57%
# 3             Rocket Lab USA, Inc.        5.44          +1.01        +22.80%
# 4                       NIKE, Inc.      108.04         -14.49        -11.83%
# 5             Riot Platforms, Inc.       17.78          +1.03         +6.15%
# 6               Ford Motor Company       12.35          +0.01         +0.08%
# 7       Carnival Corporation & plc       18.93          -0.26         -1.35%
# 8      Bank of America Corporation       33.43          +0.23         +0.69%
# 9                       Apple Inc.      193.60          -1.08         -0.55%
#
#      Volume Average_Vol    Market PE Ratio
# 0  118.602M     46.571M    5.946B      N/A
# 1    93.37M    121.135M  802.804B    81.20
# 2   56.076M     46.084M   15.038B      N/A
# 3   51.905M      4.842M    2.643B      N/A
# 4   46.666M      9.419M  164.427B    31.59
# 5   45.555M     25.801M    3.672B      N/A
# 6   43.765M      54.91M   49.436B     8.07
# 7    38.24M     32.203M   24.728B      N/A
# 8   37.266M     48.331M  264.556B     9.36
# 9    37.15M     54.136M    3.011T    31.53

# %%
#Saving to data as csv file
df.to_csv('stock.csv')
